# %%
import pandas as pd
import numpy as np
from scipy import stats
import os
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("LabTAT.csv")

# %%
data.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
stats.f_oneway(data.iloc[:,0],data.iloc[:,1],data.iloc[:,2],data.iloc[:,3])
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Laboratory 1'}>,
#         <AxesSubplot:title={'center':'Laboratory 2'}>],
#        [<AxesSubplot:title={'center':'Laboratory 3'}>,
#         <AxesSubplot:title={'center':'Laboratory 4'}>]], dtype=object)

# %%
#here pvalue is more than the given signifiacnt level so we accept alternative hypothesis and reject null hypothesis
